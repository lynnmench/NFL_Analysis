# %% [markdown]
# Date: 03Nov2022
# Author: Lynn Menchaca
#
# Resources:
#
# This is my 2nd attempt working with the NFL data set. The purpose of this document is to practice new exploratory data analysis methods along with new feature engineering methods. With these new methods see if I can improve my accuracy with the test data set.

# %% [markdown]
# #### EDA

# %%
import pandas as pd

# %%
#parse_dates=True
data_file_path = '/Users/lynnpowell/Documents/DS_Projects/NFL_Analysis/Data_Sets/'
nfl = pd.read_csv(data_file_path+'nfl_cleaned_data.csv', parse_dates=['DateTime'])

# %%
nfl.head()
# Out:
#    Season       Week            DateTime  H_WinTeam    HomeTeam  HomePts  \
# 0    2021  ConfChamp 2022-01-30 18:30:00        1.0        Rams     20.0
# 1    2021  ConfChamp 2022-01-30 15:00:00        0.0      Chiefs     24.0
# 2    2021   Division 2022-01-23 18:30:00        1.0      Chiefs     42.0
# 3    2021   Division 2022-01-23 15:00:00        0.0  Buccaneers     27.0
# 4    2021   Division 2022-01-22 20:15:00        0.0     Packers     10.0
#
#    HomeYds  HomeTO AwayTeam  AwayPts  ...  SACK_Away  PEN_Away RAW_Away  \
# 0    396.0     1.0    49ers     17.0  ...      -11.7       1.9     52.0
# 1    375.0     2.0  Bengals     27.0  ...      -22.9       1.7     57.7
# 2    552.0     0.0    Bills     36.0  ...      -10.5       0.3     61.8
# 3    359.0     2.0     Rams     30.0  ...      -13.1       1.7     64.2
# 4    263.0     1.0    49ers     13.0  ...      -11.7       1.9     52.0
#
#         QBName_Away QB_Pre_RK_Away div_game out_conf        Rest_Away  \
# ...
