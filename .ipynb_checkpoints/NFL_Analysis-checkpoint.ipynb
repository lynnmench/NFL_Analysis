# %% [markdown]
# Created: Monday 29Aug2022
#
# Author: Lynn Menchaca
#
# The purpose of this document is to analyze all the collected NFL data.

# %%
import pandas as pd
import numpy as np

# %%
data_file_path = '/Users/lynnpowell/Documents/DS_Projects/NFL_Analysis/Data_Sets/'
df_nfl = pd.read_csv(data_file_path+'nfl_cleaned_data.csv')

# %%
df_nfl.head()
# Out:
#    Season       Week             DateTime  WinTeam    LoseTeam    HomeTeam  \
# 0    2021  ConfChamp  2022-01-30 18:30:00     Rams       49ers        Rams
# 1    2021  ConfChamp  2022-01-30 15:00:00  Bengals      Chiefs      Chiefs
# 2    2021   Division  2022-01-23 18:30:00   Chiefs       Bills      Chiefs
# 3    2021   Division  2022-01-23 15:00:00     Rams  Buccaneers  Buccaneers
# 4    2021   Division  2022-01-22 20:15:00    49ers     Packers     Packers
#
#    HomePts  HomeYds  HomeTO AwayTeam  ...  RUN_Away  SACK_Away  PEN_Away  \
# 0     20.0    396.0     1.0    49ers  ...       2.7      -13.1       1.7
# 1     24.0    375.0     2.0  Bengals  ...      18.1       -9.0       4.7
# 2     42.0    552.0     0.0    Bills  ...      18.1       -9.0       4.7
# 3     27.0    359.0     2.0     Rams  ...       4.9       -8.7       3.8
# 4     10.0    263.0     1.0    49ers  ...       5.2      -12.6       5.4
#
#   RAW_Away              Name QB_Pre_RK_Away div_game out_conf  \
# 0     64.2  Matthew Stafford           15.0        1        0
# 1     63.0   Patrick Mahomes            2.0        0        0
# 2     63.0   Patrick Mahomes            2.0        0        0
# 3     67.1         Tom Brady            9.0        0        0
# 4     68.2     Aaron Rodgers            1.0        0        0
#
#          Rest_Away         Rest_Home
# 0  7 days 22:15:00   7 days 03:30:00
# 1  7 days 22:30:00   6 days 20:30:00
# 2  7 days 22:15:00   6 days 22:15:00
# 3  5 days 18:45:00   7 days 02:00:00
# 4  6 days 03:35:00  13 days 07:15:00
#
# [5 rows x 97 columns]

# %%
df_nfl.columns

# Drop all of the null valus for H_WinTeam, this is the column we are trying to predict later
