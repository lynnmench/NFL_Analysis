# %% [markdown]
# Created: Monday 29Aug2022
#
# Author: Lynn Menchaca
#
# The purpose of this document is to analyze all the collected NFL data.

# %% [markdown]
# Resources:
#
# 1)
# Author: Alex ->
# Article: Pie Charts with Labels in Matplotlib ->
# Website:
# https://www.pythoncharts.com/matplotlib/pie-chart-matplotlib/

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.image as image
from matplotlib.patches import ConnectionPatch
from matplotlib.pyplot import figure

# %%
#parse_dates=True
data_file_path = '/Users/lynnpowell/Documents/DS_Projects/NFL_Analysis/Data_Sets/'
nfl = pd.read_csv(data_file_path+'nfl_cleaned_data.csv', parse_dates=['DateTime'])

# %%
nfl.head()
# Out:
#    Season       Week            DateTime  H_WinTeam    HomeTeam  HomePts  \
# 0    2021  ConfChamp 2022-01-30 18:30:00        1.0        Rams     20.0
# 1    2021  ConfChamp 2022-01-30 15:00:00        0.0      Chiefs     24.0
# 2    2021   Division 2022-01-23 18:30:00        1.0      Chiefs     42.0
# 3    2021   Division 2022-01-23 15:00:00        0.0  Buccaneers     27.0
# 4    2021   Division 2022-01-22 20:15:00        0.0     Packers     10.0
#
#    HomeYds  HomeTO AwayTeam  AwayPts  ...  RUN_Away  SACK_Away PEN_Away  \
# 0    396.0     1.0    49ers     17.0  ...       2.7      -13.1      1.7
# 1    375.0     2.0  Bengals     27.0  ...      18.1       -9.0      4.7
# 2    552.0     0.0    Bills     36.0  ...      18.1       -9.0      4.7
# 3    359.0     2.0     Rams     30.0  ...       4.9       -8.7      3.8
# 4    263.0     1.0    49ers     13.0  ...       5.2      -12.6      5.4
#
#   RAW_Away       QBName_Away QB_Pre_RK_Away div_game  out_conf  \
# 0     64.2  Matthew Stafford           15.0        1         0
# 1     63.0   Patrick Mahomes            2.0        0         0
# 2     63.0   Patrick Mahomes            2.0        0         0
# 3     67.1         Tom Brady            9.0        0         0
# 4     68.2     Aaron Rodgers            1.0        0         0
#
#          Rest_Away         Rest_Home
# 0  7 days 22:15:00   7 days 03:30:00
# 1  7 days 22:30:00   6 days 20:30:00
# 2  7 days 22:15:00   6 days 22:15:00
# 3  5 days 18:45:00   7 days 02:00:00
# 4  6 days 03:35:00  13 days 07:15:00
#
# [5 rows x 96 columns]

# %%
nfl.columns
# Out:
# Index(['Season', 'Week', 'DateTime', 'H_WinTeam', 'HomeTeam', 'HomePts',
#        'HomeYds', 'HomeTO', 'AwayTeam', 'AwayPts', 'AwayYds', 'AwayTO',
#        'Capacity', 'Opened', 'Turf', 'Cost', 'Stadium_Roof', 'Fan_Repu',
#        'Weather', 'Location', 'Div_Home', 'Conf_Home', 'Rank_Off_Home',
#        'Yards/G_Off_Home', 'Rush/G_Off_Home', 'Rush/P_Off_Home',
#        'Pass/G_Off_Home', 'QBR_Off_Home', 'Sacks_Off_Home', '3rd%_Off_Home',
#        'Poss/G_Off_Home', 'Pts/G_Off_Home', 'Off_Pre_RK_Home', 'Rank_Def_Home',
#        'Yards/G_Def_Home', 'Rush/G_Def_Home', 'Rush/P_Def_Home',
#        'Pass/G_Def_Home', 'QBR_Def_Home', 'Sacks_Def_Home', '3rd%_Def_Home',
#        'Poss/G_Def_Home', 'Pts/G_Def_Home', 'Def_Pre_RK_Home', 'RK_Home',
#        'QBR_Home', 'PAA_Home', 'Plays_Home', 'EPA_Home', 'PASS_Home',
#        'RUN_Home', 'SACK_Home', 'PEN_Home', 'RAW_Home', 'QBName_Home',
#        'QB_Pre_RK_Home', 'Div_Away', 'Conf_Away', 'Rank_Off_Away',
#        'Yards/G_Off_Away', 'Rush/G_Off_Away', 'Rush/P_Off_Away',
#        'Pass/G_Off_Away', 'QBR_Off_Away', 'Sacks_Off_Away', '3rd%_Off_Away',
#        'Poss/G_Off_Away', 'Pts/G_Off_Away', 'Off_Pre_RK_Away', 'Rank_Def_Away',
#        'Yards/G_Def_Away', 'Rush/G_Def_Away', 'Rush/P_Def_Away',
#        'Pass/G_Def_Away', 'QBR_Def_Away', 'Sacks_Def_Away', '3rd%_Def_Away',
#        'Poss/G_Def_Away', 'Pts/G_Def_Away', 'Def_Pre_RK_Away', 'RK_Away',
#        'QBR_Away', 'PAA_Away', 'Plays_Away', 'EPA_Away', 'PASS_Away',
#        'RUN_Away', 'SACK_Away', 'PEN_Away', 'RAW_Away', 'QBName_Away',
#        'QB_Pre_RK_Away', 'div_game', 'out_conf', 'Rest_Away', 'Rest_Home'],
#       dtype='object')

# %%
# Drop all of the null valus for H_WinTeam, this is the column we are trying to predict later
print("Tie games or other: " + str(nfl['H_WinTeam'].isnull().sum()))
nfl = nfl.dropna(subset=['H_WinTeam'], axis=0)
print("Missing winning games: " + str(nfl['H_WinTeam'].isnull().sum()))
# Out:
# Tie games or other: 10
# Missing winning games: 0

# %%
nfl.shape
# Out:
# (3999, 96)

# %%
#Creating a function that takes delta of the win and losing teams stats
def delta_wl(col_name, home, away):
    nfl[col_name] = nfl.apply(lambda x: x[home]-x[away] if x['H_WinTeam']==1
                             else x[away] - x[home], axis=1)

# %%
#Using resource from Alex -> Pie Charts with Labels in Matplotlib
#Pie chart of Home Team winning vs Away
print('Home Games Won: ' + str(nfl['H_WinTeam'].value_counts()[1]))
print('Away Games Won: ' + str(nfl['H_WinTeam'].value_counts()[0]))
labels = ['Home', 'Away']
values = [nfl['H_WinTeam'].value_counts()[1], nfl['H_WinTeam'].value_counts()[0]]

fig, ax = plt.subplots(figsize=(6, 6))
patches, texts, pcts = ax.pie(
    x=values, labels=labels, autopct='%.2f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90)
plt.setp(pcts, color='white', fontweight='bold')
ax.set_title('Home Team Vs Away Team', fontsize=18)
plt.tight_layout()
#plt.pie(x=values, labels=labels, autopct='%.2f%%', textprops={'size': 'x-large'})
#plt.setp(pct, color='white', fontweight='bold')
#plt.show()
# Out:
# Home Games Won: 2247
# Away Games Won: 1752

# %%
#Only using the games the conferences don't match for home and away
out_conf_headers = ['Season','H_WinTeam','Conf_Home','Conf_Away', 'Div_Home', 'Div_Away','HomeTeam','AwayTeam']
out_conf = nfl[out_conf_headers][nfl['Conf_Home']!=nfl['Conf_Away']]
print(out_conf.head())

#Make a table of just the win, divisions and conferences - Away
out_conf_away = out_conf[['Season','H_WinTeam','Conf_Away', 'Div_Away','AwayTeam'
                 ]][out_conf['H_WinTeam']==0]
out_conf_away = out_conf_away.rename({'H_WinTeam':'H_Win', 'Conf_Away':'Conf', 'Div_Away':'Div', 'AwayTeam':'Team'},axis=1)
print(out_conf_away.head())

#Make a table of just the win, divisions and conferences - Home
out_conf_home = out_conf[['Season','H_WinTeam','Conf_Home', 'Div_Home', 'HomeTeam'
                 ]][out_conf['H_WinTeam']==1]
out_conf_home = out_conf_home.rename({'H_WinTeam':'H_Win', 'Conf_Home':'Conf', 'Div_Home':'Div','HomeTeam':'Team'},axis=1)
print(out_conf_home.head())

#combinning both files to make the data easier to plot and analyze
out_conf_stats = pd.concat([out_conf_home, out_conf_away], axis=0)
#The number of rows matches the full data frame 'nfl'
print(out_conf_stats.shape)
#print(out_conf_stat.head())
# Out:
#     Season  H_WinTeam Conf_Home Conf_Away   Div_Home   Div_Away HomeTeam  \
# 30    2021        0.0       AFC       NFC  AFC North   NFC West   Ravens
# 32    2021        1.0       NFC       AFC   NFC West  AFC South    49ers
# 34    2021        1.0       AFC       NFC   AFC East  NFC South    Bills
# 43    2021        0.0       AFC       NFC   AFC East  NFC South     Jets
# 44    2021        0.0       NFC       AFC  NFC South   AFC East   Saints
#
#       AwayTeam
# 30        Rams
# 32      Texans
# 34     Falcons
# 43  Buccaneers
# 44    Dolphins
#     Season  H_Win Conf        Div        Team
# 30    2021    0.0  NFC   NFC West        Rams
# 43    2021    0.0  NFC  NFC South  Buccaneers
# 44    2021    0.0  AFC   AFC East    Dolphins
# 57    2021    0.0  AFC  AFC South       Colts
# 71    2021    0.0  NFC  NFC North     Packers
#     Season  H_Win Conf        Div     Team
# 32    2021    1.0  NFC   NFC West    49ers
# 34    2021    1.0  AFC   AFC East    Bills
# 58    2021    1.0  NFC  NFC North  Packers
# 59    2021    1.0  AFC  AFC South   Titans
# 72    2021    1.0  AFC   AFC East    Bills
# (971, 5)

# %%
#Examing the data for the out of conference games

#out_conf_stats['Conf'].groupby(out_conf['DateTime'].dt.year).value_counts()
out_conf_stats['Conf'].groupby(out_conf_stats['Season']).value_counts().unstack()
# Out:
# Conf    AFC  NFC
# Season
# 2007     32   32
# 2008     34   29
# 2009     37   27
# 2010     34   30
# 2011     31   33
# 2012     25   39
# 2013     30   34
# 2014     33   30
# 2015     29   35
# 2016     33   30
# 2017     23   41
# 2018     34   30
# 2019     31   33
# 2020     35   28
# 2021     39   40

# %%
#Ploting the data for the out of conference games

#out_conf_stats['Conf'].groupby(out_conf_stats['Season']).value_counts().plot.bar()
fig = plt.subplots(1, 1, figsize=(9,5))
plt.plot(out_conf_stats['Conf'].groupby(out_conf_stats['Season']).value_counts().unstack()['AFC'], color='red', label='AFC')
plt.plot(out_conf_stats['Conf'].groupby(out_conf_stats['Season']).value_counts().unstack()['NFC'], color='blue', label='NFC')
plt.legend()
plt.title('Games Played Between NFC and AFC Teams')
plt.ylabel('# of Games Won')
plt.xlabel('Season')
plt.xticks(np.arange(min(out_conf_stats['Season']), max(out_conf_stats['Season'])+1))
#width = 10
#height = 6
#fig.set_size_inches(width, height)
#figure(figsize=(10, 6), dpi=160)
plt.show()

# %%
#Overall comparison of games the NFC and AFC played
#Only using the games the conferences don't match for home and away

#afc_sum = out_conf['Conf_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC'] + out_conf['Conf_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC']
#nfc_sum = out_conf['Conf_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC'] + out_conf['Conf_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC']

afc_sum = out_conf_stats['Conf'].value_counts()['AFC']
nfc_sum = out_conf_stats['Conf'].value_counts()['NFC']

print('NFC Games Won: ' + str(nfc_sum))
print('AFC Games Won: ' + str(afc_sum))

#Pie Chart
labels = ['National Football Confrence_NFC', 'American Football Confrence_AFC']
values = [nfc_sum, afc_sum]

fig, ax = plt.subplots(figsize=(6, 6))
patches, texts, pcts = ax.pie(
    x=values, autopct='%.2f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90)
plt.setp(pcts, color='white', fontweight='bold')
ax.set_title('Games Played Between NFC and AFC Teams', fontsize=18)
ax.legend(patches, labels,
          title="NFL Confrences",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.tight_layout()
# Out:
# NFC Games Won: 491
# AFC Games Won: 480

# %%
#Looking at division winners for games played outside of Conference
print(out_conf_stats['Div'].value_counts())
print(out_conf_stats['Team'][out_conf_stats['Div']=='AFC North'].value_counts())
print(out_conf_stats['Team'][out_conf_stats['Div']=='AFC South'].value_counts())
# Out:
# AFC North    126
# NFC West     125
# AFC East     125
# NFC North    125
# NFC South    124
# AFC West     119
# NFC East     117
# AFC South    110
# Name: Div, dtype: int64
# Steeler    39
# Ravens     39
# Bengals    27
# Browns     21
# Name: Team, dtype: int64
# Titans     37
# Colts      36
# Texans     25
# Jaguars    12
# Name: Team, dtype: int64

# %%
#Looking at the top 10 teams for winning games played outside of conference
#out_conf_stats['Team'].value_counts().head(10)
out_conf_stats['Team'].groupby(out_conf_stats['Conf']).value_counts().sort_values(ascending=False).head(13)
# Out:
# Conf  Team
# AFC   Patriots     44
# NFC   Packers      40
# AFC   Steeler      39
#       Ravens       39
#       Chiefs       37
# NFC   Saints       37
# AFC   Titans       37
#       Colts        36
#       Broncos      34
# NFC   Seahawks     34
#       Cardinals    34
#       Eagles       34
#       Bears        33
# Name: Team, dtype: int64

# %% [markdown]
# --------------------------------------------------------------------------------------------
#
# Based off the data above, it looks like the NFC is the conference with the most wins. Looking at the rest of the data I am a little suprised by this becusae the AFC has the division (AFC North) with the most out of conference wins. The AFC also has 7 teams in the top 9.
#
# It looks like what hurst the AFC conference is the AFC South division. The total difference of wins between the AFC and NFC is 11 points and AFC South is 7 points of that point difference. The NFC also has the 3 divisions in the top 5, helping NFC catch up to AFC.
#
# It is interesting to see every other year the NFC and AFC alterate who has the most total wins for that season. Next is analyzing the divisions, the goal is to see if this is from drafting new players (the teams on the bottom help bring up the over all performance) or if this is from the middle teams have a good team and a densent draft position or is this from the top teams continuing to improve?

# %%
#Only using the games played in the same conference and outside of the division
out_div_headers = ['Season','H_WinTeam','Conf_Home','Conf_Away', 'Div_Home', 'Div_Away','HomeTeam','AwayTeam']
out_div = nfl[out_div_headers][(nfl['Conf_Home']==nfl['Conf_Away']) & (nfl['Div_Home'] != nfl['Div_Away'])]
print(out_div.head(10))

#Make a table of just the win, divisions and conferences - Away
out_div_away = out_div[['Season','H_WinTeam','Conf_Away', 'Div_Away','AwayTeam'
                 ]][out_div['H_WinTeam']==0]
out_div_away = out_div_away.rename({'H_WinTeam':'H_Win', 'Conf_Away':'Conf', 'Div_Away':'Div', 'AwayTeam':'Team'},axis=1)
print(out_div_away.head())

#Make a table of just the win, divisions and conferences - Home
out_div_home = out_div[['Season','H_WinTeam','Conf_Home', 'Div_Home', 'HomeTeam'
                 ]][out_div['H_WinTeam']==1]
out_div_home = out_div_home.rename({'H_WinTeam':'H_Win', 'Conf_Home':'Conf', 'Div_Home':'Div','HomeTeam':'Team'},axis=1)
print(out_div_home.head())

#combinning both files to make the data easier to plot and analyze
out_div_stats = pd.concat([out_conf_home, out_conf_away], axis=0)
#The number of rows matches the full data frame 'nfl'
print(out_div_stats.shape)
#print(out_conf_stat.head())
# Out:
#     Season  H_WinTeam Conf_Home Conf_Away   Div_Home   Div_Away    HomeTeam  \
# 1     2021        0.0       AFC       AFC   AFC West  AFC North      Chiefs
# 2     2021        1.0       AFC       AFC   AFC West   AFC East      Chiefs
# 3     2021        0.0       NFC       NFC  NFC South   NFC West  Buccaneers
# 4     2021        0.0       NFC       NFC  NFC North   NFC West     Packers
# 5     2021        0.0       AFC       AFC  AFC South  AFC North      Titans
# 7     2021        1.0       AFC       AFC   AFC West  AFC North      Chiefs
# 8     2021        0.0       NFC       NFC   NFC East   NFC West     Cowboys
# 9     2021        1.0       NFC       NFC  NFC South   NFC East  Buccaneers
# 11    2021        1.0       AFC       AFC  AFC North   AFC West     Bengals
# 31    2021        1.0       NFC       NFC   NFC West  NFC North    Seahawks
#
#    AwayTeam
# 1   Bengals
# 2     Bills
# 3      Rams
# 4     49ers
# 5   Bengals
# 7   Steeler
# 8     49ers
# 9    Eagles
# 11  Raiders
# 31    Lions
#    Season  H_Win Conf        Div     Team
# 1    2021    0.0  AFC  AFC North  Bengals
# 3    2021    0.0  NFC   NFC West     Rams
# 4    2021    0.0  NFC   NFC West    49ers
# 5    2021    0.0  AFC  AFC North  Bengals
# 8    2021    0.0  NFC   NFC West    49ers
#     Season  H_Win Conf        Div        Team
# 2     2021    1.0  AFC   AFC West      Chiefs
# 7     2021    1.0  AFC   AFC West      Chiefs
# 9     2021    1.0  NFC  NFC South  Buccaneers
# 11    2021    1.0  AFC  AFC North     Bengals
# 31    2021    1.0  NFC   NFC West    Seahawks
# (971, 5)

# %%
#In conference but out of division stats broken out by season
out_div_stats['Div'].groupby(out_div_stats['Season']).value_counts().unstack()
# Out:
# Div     AFC East  AFC North  AFC South  AFC West  NFC East  NFC North  \
# Season
# 2007           5         10         13         4        11         12
# 2008          11          7         11         5         8          5
# 2009           9          8         12         8         8          8
# 2010           9          9          7         9         9          7
# 2011           8         10          5         8         8          8
# 2012           6          8          6         5         8         10
# 2013           8          8          3        11         5          8
# 2014           9         12          4         8        12          7
# 2015           9          8          6         6         7         10
# 2016          10          4          9        10        11          7
# 2017           6          6          4         7         9         10
# 2018           7          9         10         8         6          9
# 2019          11          6          6         8         5          8
# 2020           8         11          8         8         4          8
# 2021           9         10          6        14         6          8
#
# Div     NFC South  NFC West
# Season
# 2007            3         6
# 2008           11         5
# 2009            7         4
# 2010            7         7
# 2011           11         6
# 2012           11        10
# 2013            8        13
# 2014            3         8
# 2015           10         8
# 2016            6         6
# 2017           10        12
# 2018            7         8
# 2019           10        10
# 2020            8         8
# 2021           12        14

# %%
#Plotting the AFC and NFC division win count for each season

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10,5))
fig.suptitle('Games Played In Conference Out of Division')

#AFC Divisions
ax1.plot(out_div_stats['Div'].groupby(out_div_stats['Season']).value_counts().unstack()['AFC East'], color='red', label='AFC East')
ax1.plot(out_div_stats['Div'].groupby(out_div_stats['Season']).value_counts().unstack()['AFC West'], color='blue', label='AFC West')
ax1.plot(out_div_stats['Div'].groupby(out_div_stats['Season']).value_counts().unstack()['AFC North'], color='green', label='AFC North')
ax1.plot(out_div_stats['Div'].groupby(out_div_stats['Season']).value_counts().unstack()['AFC South'], color='black', label='AFC South')
#ax1.legend(bbox_to_anchor=(1.1, 1.05))
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15),
          ncol=4, fancybox=True, shadow=True)
ax1.set(xlabel=' ', ylabel='# of AFC Games Won')
#plt.ylabel('# of Games Won')
#plt.xlabel('Season')
ax1.xaxis.set_ticks(np.arange(min(out_div_stats['Season']), max(out_div_stats['Season'])+1))

#NFC Divisions
ax2.plot(out_div_stats['Div'].groupby(out_div_stats['Season']).value_counts().unstack()['NFC East'], color='red', label='NFC East')
ax2.plot(out_div_stats['Div'].groupby(out_div_stats['Season']).value_counts().unstack()['NFC West'], color='blue', label='NFC West')
ax2.plot(out_div_stats['Div'].groupby(out_div_stats['Season']).value_counts().unstack()['NFC North'], color='green', label='NFC North')
ax2.plot(out_div_stats['Div'].groupby(out_div_stats['Season']).value_counts().unstack()['NFC South'], color='black', label='NFC South')
ax2.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15),
          ncol=4, fancybox=True, shadow=True)
ax2.set(xlabel=' ', ylabel='# of AFC Games Won')
#plt.ylabel('# of Games Won')
#plt.xlabel('Season')
plt.xticks(np.arange(min(out_div_stats['Season']), max(out_div_stats['Season'])+1))
ax2.set(xlabel='Seasons', ylabel='# of NFC Games Won')

fig.tight_layout()
ax1.grid()
ax2.grid()
plt.show()

# %%
#Examing the data for in conference but out of division games

#out_div_stats['Div'].groupby(out_conf_stats['Season']).value_counts().unstack()
print(out_div_stats['Div'].value_counts())

#The results appear to be the same as the out of Conference games
print('\n')
print('AFC North Teams')
print(out_conf_stats['Team'][out_conf_stats['Div']=='AFC North'].value_counts())
print('NFC West Teams')
print(out_conf_stats['Team'][out_conf_stats['Div']=='NFC West'].value_counts())
print('NFC North Teams')
print(out_conf_stats['Team'][out_conf_stats['Div']=='NFC North'].value_counts())
# Out:
# AFC North    126
# NFC West     125
# AFC East     125
# NFC North    125
# NFC South    124
# AFC West     119
# NFC East     117
# AFC South    110
# Name: Div, dtype: int64
#
#
# AFC North Teams
# Steeler    39
# Ravens     39
# Bengals    27
# Browns     21
# Name: Team, dtype: int64
# NFC West Teams
# Seahawks     34
# Cardinals    34
# 49ers        31
# Rams         26
# Name: Team, dtype: int64
# NFC North Teams
# Packers    40
# Bears      33
# Vikings    31
# Lions      21
# Name: Team, dtype: int64

# %%
#Looking to see what divisions has the won the most games in the NFC

#divisions in AFC
afc_north = out_div_stats['Div'].value_counts()['AFC North']
afc_south = out_div_stats['Div'].value_counts()['AFC South']
afc_east = out_div_stats['Div'].value_counts()['AFC East']
afc_west = out_div_stats['Div'].value_counts()['AFC West']

#teams in NFC West
#calculating the win percentage for each team = 
# = total team wins from out_div_stats dataframe / total games team played nfl data frame
pit = out_div_stats['Team'][out_div_stats['Div']=='AFC North'].value_counts()['Steeler'] / nfl[(nfl['HomeTeam']=='Steeler')|(nfl['AwayTeam']=='Steeler')].shape[0]
bal = out_div_stats['Team'][out_div_stats['Div']=='AFC North'].value_counts()['Ravens'] / nfl[(nfl['HomeTeam']=='Ravens')|(nfl['AwayTeam']=='Ravens')].shape[0]
cin = out_div_stats['Team'][out_div_stats['Div']=='AFC North'].value_counts()['Bengals'] / nfl[(nfl['HomeTeam']=='Bengals')|(nfl['AwayTeam']=='Bengals')].shape[0]
cle = out_div_stats['Team'][out_div_stats['Div']=='AFC North'].value_counts()['Browns'] / nfl[(nfl['HomeTeam']=='Browns')|(nfl['AwayTeam']=='Browns')].shape[0]

afc_labels = ['AFC South', 'AFC North', 'AFC East', 'AFC West']
afc_values = [afc_south, afc_north, afc_east, afc_west]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9,5))
fig.subplots_adjust(wspace=0)

# Get four different grey colors.
cmap = plt.get_cmap('Greys')
colors = list(cmap(np.linspace(0.45, 0.85, len(afc_values))))
# Swap in a bright blue for the Lacrosse color.
colors[1] = 'dodgerblue'

# You could also just manually assign colors very easily.
# colors = ['purple', 'black', 'pink', 'aqua']

patches, texts, pcts = ax2.pie(
    afc_values, labels=afc_labels, autopct='%.1f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90,
    colors=colors,
    #explode is use to select what wedge slides out
    explode=(0, 0.1, 0, 0))

for i, patch in enumerate(patches):
  # You could also do something like this if you want to assign colors
  # by some rule or by value.
  # if texts[i].get_text() == 'Lacrosse':
  #   patch.set_facecolor('dodgerblue')
  texts[i].set_color(patch.get_facecolor())
plt.setp(pcts, color='white')
plt.setp(texts, fontweight=600)
ax2.set_title('AFC Division % Total Wins', fontsize=18)
plt.tight_layout()


#Creating bar chart for games won by each nfc south team
afcnorth_labels = ['Steeler', 'Ravens', 'Bengals', 'Browns']
afcnorth_values = [pit, bal, cin, cle]
bottom = 1
width = 0.5

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(afcnorth_values, afcnorth_labels)])):
    bottom -= height
    bc = ax1.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax1.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax1.set_title('AFC Total Team Wins %')
ax1.legend(bbox_to_anchor=(0.2, 1), loc='upper right', borderaxespad=0)
ax1.axis('off')
ax1.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = patches[0].theta1, patches[0].theta2
center, r = patches[0].center, patches[0].r
bar_height = sum(afcnorth_values)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
#xyA,xyB = (x-axis, y-axis) use this to adjust the start and end point of the line
con = ConnectionPatch(xyA=(-width / 0.47, -0.1), coordsA=ax2.transData,
                      xyB=(x+0.25, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

# draw bottom connecting line
#x = r * np.cos(np.pi / 180 * theta2) + center[0]
#y = r * np.sin(np.pi / 180 * theta2) + center[1]
#xyA,xyB = (x-axis, y-axis) use this to adjust the start and end point of the line
con = ConnectionPatch(xyA=(-0.1, -1.1), coordsA=ax2.transData,
                      xyB=(0.26, 0.51), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

plt.show()

# %%
#Looking to see what divisions has the won the most games in the NFC

#divisions in NFC
nfc_north = out_div_stats['Div'].value_counts()['NFC North']
nfc_south = out_div_stats['Div'].value_counts()['NFC South']
nfc_east = out_div_stats['Div'].value_counts()['NFC East']
nfc_west = out_div_stats['Div'].value_counts()['NFC West']

#teams in NFC West
#calculating the win percentage for each team = 
# = total team wins from out_div_stats dataframe / total games team played nfl data frame
no = out_div_stats['Team'][out_div_stats['Div']=='NFC South'].value_counts()['Saints'] / nfl[(nfl['HomeTeam']=='Saints')|(nfl['AwayTeam']=='Saints')].shape[0]
atl = out_div_stats['Team'][out_div_stats['Div']=='NFC South'].value_counts()['Falcons'] / nfl[(nfl['HomeTeam']=='Falcons')|(nfl['AwayTeam']=='Falcons')].shape[0]
car = out_div_stats['Team'][out_div_stats['Div']=='NFC South'].value_counts()['Panthers'] / nfl[(nfl['HomeTeam']=='Panthers')|(nfl['AwayTeam']=='Panthers')].shape[0]
tb = out_div_stats['Team'][out_div_stats['Div']=='NFC South'].value_counts()['Buccaneers'] / nfl[(nfl['HomeTeam']=='Buccaneers')|(nfl['AwayTeam']=='Buccaneers')].shape[0]

nfc_labels = ['NFC South', 'NFC North', 'NFC East', 'NFC West']
nfc_values = [nfc_south, nfc_north, nfc_east, nfc_west]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9,5))
fig.subplots_adjust(wspace=0)

# Get four different grey colors.
cmap = plt.get_cmap('Greys')
colors = list(cmap(np.linspace(0.45, 0.85, len(nfc_values))))
# Swap in a bright blue for the Lacrosse color.
colors[1] = 'dodgerblue'

# You could also just manually assign colors very easily.
# colors = ['purple', 'black', 'pink', 'aqua']

patches, texts, pcts = ax2.pie(
    nfc_values, labels=nfc_labels, autopct='%.1f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90,
    colors=colors,
    #explode is use to select what wedge slides out
    explode=(0, 0.1, 0, 0))

for i, patch in enumerate(patches):
  # You could also do something like this if you want to assign colors
  # by some rule or by value.
  # if texts[i].get_text() == 'Lacrosse':
  #   patch.set_facecolor('dodgerblue')
  texts[i].set_color(patch.get_facecolor())
plt.setp(pcts, color='white')
plt.setp(texts, fontweight=600)
ax2.set_title('NFC Division % Total Wins', fontsize=18)
plt.tight_layout()


#Creating bar chart for games won by each nfc south team
nfcsouth_labels = ['Saint', 'Falcons', 'Panthers', 'Buccaneers']
nfcsouth_values = [no, atl, car, tb]
bottom = 1
width = 0.5

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(nfcsouth_values, nfcsouth_labels)])):
    bottom -= height
    bc = ax1.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax1.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax1.set_title('NFC Total Team Wins %')
ax1.legend(bbox_to_anchor=(0.2, 1), loc='upper right', borderaxespad=0)
ax1.axis('off')
ax1.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = patches[0].theta1, patches[0].theta2
center, r = patches[0].center, patches[0].r
bar_height = sum(nfcsouth_values)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
#xyA,xyB = (x-axis, y-axis) use this to adjust the start and end point of the line
con = ConnectionPatch(xyA=(-width / 0.47, -0.1), coordsA=ax2.transData,
                      xyB=(x+0.25, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

# draw bottom connecting line
#x = r * np.cos(np.pi / 180 * theta2) + center[0]
#y = r * np.sin(np.pi / 180 * theta2) + center[1]
#xyA,xyB = (x-axis, y-axis) use this to adjust the start and end point of the line
con = ConnectionPatch(xyA=(-0.1, -1.1), coordsA=ax2.transData,
                      xyB=(0.26, 0.51), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

plt.show()

# %% [markdown]
# The size is the same out of conference and in conference out of division.

# %%
#Make a table of just the team names, win, divisions and conferences - Home
df_hometeam = nfl[['H_WinTeam','Conf_Home', 'Div_Home', 'HomeTeam'
                 ]][nfl['H_WinTeam']==1]
df_hometeam = df_hometeam.rename({'H_WinTeam':'H_Win', 'Conf_Home':'Conf', 'Div_Home':'Div', 'HomeTeam':'Team'},axis=1)

# %%
df_hometeam.head()
# Out:
#    H_Win Conf        Div        Team
# 0    1.0  NFC   NFC West        Rams
# 2    1.0  AFC   AFC West      Chiefs
# 6    1.0  NFC   NFC West        Rams
# 7    1.0  AFC   AFC West      Chiefs
# 9    1.0  NFC  NFC South  Buccaneers

# %%
#Make a table of just the team names, win, divisions and conferences - Away
df_awayteam = nfl[['H_WinTeam','Conf_Away', 'Div_Away', 'AwayTeam'
                 ]][nfl['H_WinTeam']==0]
df_awayteam = df_awayteam.rename({'H_WinTeam':'H_Win', 'Conf_Away':'Conf', 'Div_Away':'Div', 'AwayTeam':'Team'},axis=1)

# %%
df_awayteam.head()
# Out:
#    H_Win Conf        Div     Team
# 1    0.0  AFC  AFC North  Bengals
# 3    0.0  NFC   NFC West     Rams
# 4    0.0  NFC   NFC West    49ers
# 5    0.0  AFC  AFC North  Bengals
# 8    0.0  NFC   NFC West    49ers

# %%
#combinning both files to make the data easier to plot and analyze
team_stat = pd.concat([df_hometeam, df_awayteam], axis=0)
#The number of rows matches the full data frame 'nfl'
team_stat.shape
# Out:
# (3999, 4)

# %%
#The number of rows matches the full data frame 'nfl'
print(team_stat['Div'].value_counts())
# Out:
# AFC East     520
# NFC South    510
# AFC North    509
# NFC West     506
# NFC North    501
# AFC West     494
# NFC East     486
# AFC South    473
# Name: Div, dtype: int64

# %%
team_stat['Team'][team_stat['Div']=='NFC South'].value_counts()
# Out:
# Saints        156
# Falcons       128
# Panthers      118
# Buccaneers    108
# Name: Team, dtype: int64

# %%
team_stat['Team'][team_stat['Div']=='AFC East'].value_counts()
# Out:
# Patriots    194
# Bills       118
# Dolphins    108
# Jets        100
# Name: Team, dtype: int64

# %%
#Looking to see what divisions has the won the most games in the NFC

#divisions in NFC
nfc_north = team_stat['Div'].value_counts()['NFC North']
nfc_south = team_stat['Div'].value_counts()['NFC South']
nfc_east = team_stat['Div'].value_counts()['NFC East']
nfc_west = team_stat['Div'].value_counts()['NFC West']

#teams in NFC South
#calculation = total wins from team_stat dataframe / total games played nfl data frame
no = team_stat['Team'][team_stat['Div']=='NFC South'].value_counts()['Saints'] / nfl[(nfl['HomeTeam']=='Saints')|(nfl['AwayTeam']=='Saints')].shape[0]
atl = team_stat['Team'][team_stat['Div']=='NFC South'].value_counts()['Falcons'] / nfl[(nfl['HomeTeam']=='Falcons')|(nfl['AwayTeam']=='Falcons')].shape[0]
car = team_stat['Team'][team_stat['Div']=='NFC South'].value_counts()['Panthers'] / nfl[(nfl['HomeTeam']=='Panthers')|(nfl['AwayTeam']=='Panthers')].shape[0]
tb = team_stat['Team'][team_stat['Div']=='NFC South'].value_counts()['Buccaneers'] / nfl[(nfl['HomeTeam']=='Buccaneers')|(nfl['AwayTeam']=='Buccaneers')].shape[0]

nfc_labels = ['NFC North', 'NFC South', 'NFC East', 'NFC West']
nfc_values = [nfc_north, nfc_south, nfc_east, nfc_west]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9,5))
fig.subplots_adjust(wspace=0)

# Get four different grey colors.
cmap = plt.get_cmap('Greys')
colors = list(cmap(np.linspace(0.45, 0.85, len(nfc_values))))
# Swap in a bright blue for the Lacrosse color.
colors[1] = 'dodgerblue'

# You could also just manually assign colors very easily.
# colors = ['purple', 'black', 'pink', 'aqua']

patches, texts, pcts = ax2.pie(
    nfc_values, labels=nfc_labels, autopct='%.1f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90,
    colors=colors,
    #explode is use to select what wedge slides out
    explode=(0, 0.1, 0, 0))

for i, patch in enumerate(patches):
  # You could also do something like this if you want to assign colors
  # by some rule or by value.
  # if texts[i].get_text() == 'Lacrosse':
  #   patch.set_facecolor('dodgerblue')
  texts[i].set_color(patch.get_facecolor())
plt.setp(pcts, color='white')
plt.setp(texts, fontweight=600)
ax2.set_title('NFC Division % Total Wins', fontsize=18)
plt.tight_layout()


#Creating bar chart for games won by each nfc south team
nfcsouth_labels = ['Saint', 'Falcons', 'Panthers', 'Buccaneers']
nfcsouth_values = [no, atl, car, tb]
bottom = 1
width = 0.5

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(nfcsouth_values, nfcsouth_labels)])):
    bottom -= height
    bc = ax1.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax1.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax1.set_title('NFC Total Team Wins %')
ax1.legend(bbox_to_anchor=(0.2, 1), loc='upper right', borderaxespad=0)
ax1.axis('off')
ax1.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = patches[0].theta1, patches[0].theta2
center, r = patches[0].center, patches[0].r
bar_height = sum(nfcsouth_values)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
#xyA,xyB = (x-axis, y-axis) use this to adjust the start and end point of the line
con = ConnectionPatch(xyA=(-width / 0.47, -0.1), coordsA=ax2.transData,
                      xyB=(x+0.25, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

# draw bottom connecting line
#x = r * np.cos(np.pi / 180 * theta2) + center[0]
#y = r * np.sin(np.pi / 180 * theta2) + center[1]
#xyA,xyB = (x-axis, y-axis) use this to adjust the start and end point of the line
con = ConnectionPatch(xyA=(-0.1, -1.1), coordsA=ax2.transData,
                      xyB=(0.3, -1), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

plt.show()

# %%
#Looking to see what divisions has the won the most games in the AFC

#divisions in AFC
afc_north = team_stat['Div'].value_counts()['AFC North']
afc_south = team_stat['Div'].value_counts()['AFC South']
afc_east = team_stat['Div'].value_counts()['AFC East']
afc_west = team_stat['Div'].value_counts()['AFC West']

#teams in NFC South
#calculation = total wins from team_stat dataframe / total games played nfl data frame
ne = team_stat['Team'][team_stat['Div']=='AFC East'].value_counts()['Patriots'] / nfl[(nfl['HomeTeam']=='Patriots')|(nfl['AwayTeam']=='Patriots')].shape[0]
buf = team_stat['Team'][team_stat['Div']=='AFC East'].value_counts()['Bills'] / nfl[(nfl['HomeTeam']=='Bills')|(nfl['AwayTeam']=='Bills')].shape[0]
mia = team_stat['Team'][team_stat['Div']=='AFC East'].value_counts()['Dolphins'] / nfl[(nfl['HomeTeam']=='Dolphins')|(nfl['AwayTeam']=='Dolphins')].shape[0]
nyj = team_stat['Team'][team_stat['Div']=='AFC East'].value_counts()['Jets'] / nfl[(nfl['HomeTeam']=='Jets')|(nfl['AwayTeam']=='Jets')].shape[0]

nfc_labels = ['AFC North', 'AFC South', 'AFC East', 'AFC West']
nfc_values = [afc_north, afc_south, afc_east, afc_west]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9,5))
fig.subplots_adjust(wspace=0)

# Get four different grey colors.
cmap = plt.get_cmap('Greys')
colors = list(cmap(np.linspace(0.45, 0.85, len(nfc_values))))
# Swap in a bright blue for the Lacrosse color.
colors[2] = 'dodgerblue'

# You could also just manually assign colors very easily.
# colors = ['purple', 'black', 'pink', 'aqua']

patches, texts, pcts = ax1.pie(
    nfc_values, labels=nfc_labels, autopct='%.1f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90,
    colors=colors,
    #explode is use to select what wedge slides out
    explode=(0, 0, 0.1, 0))

for i, patch in enumerate(patches):
  # You could also do something like this if you want to assign colors
  # by some rule or by value.
  # if texts[i].get_text() == 'Lacrosse':
  #   patch.set_facecolor('dodgerblue')
  texts[i].set_color(patch.get_facecolor())
plt.setp(pcts, color='white')
plt.setp(texts, fontweight=600)
ax1.set_title('NFC Division % Total Wins', fontsize=18)
plt.tight_layout()


#Creating bar chart for games won by each nfc south team
nfcsouth_labels = ['Patriots', 'Bills', 'Dolphins', 'Jets']
nfcsouth_values = [ne, buf, mia, nyj]
bottom = 1
width = 0.5

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(nfcsouth_values, nfcsouth_labels)])):
    bottom -= height
    bc = ax1.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('NFC Total Team Wins %')
ax2.legend(bbox_to_anchor=(0.2, 1), loc='upper right', borderaxespad=0)
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = patches[0].theta1, patches[0].theta2
center, r = patches[0].center, patches[0].r
bar_height = sum(nfcsouth_values)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
#xyA,xyB = (x-axis, y-axis) use this to adjust the start and end point of the line
con = ConnectionPatch(xyA=(-width / 0.47, -0.1), coordsA=ax2.transData,
                      xyB=(x+0.25, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

# draw bottom connecting line
#x = r * np.cos(np.pi / 180 * theta2) + center[0]
#y = r * np.sin(np.pi / 180 * theta2) + center[1]
#xyA,xyB = (x-axis, y-axis) use this to adjust the start and end point of the line
con = ConnectionPatch(xyA=(-0.1, -1.1), coordsA=ax2.transData,
                      xyB=(0.3, -1), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Looking to see what divisions in each confrences is the strongest when against other divisions
#Comparing games only played in their own conference but not in their own division
conf_games = nfl[['H_WinTeam','Conf_Home','Conf_Away', 'Div_Home', 'Div_Away', 'HomeTeam', 'AwayTeam'
                 ]][(nfl['Conf_Home']==nfl['Conf_Away']) & (nfl['Div_Home']!=nfl['Div_Away'])]


#Calculating values counts for each conference and division in the NFL
afc_north = (conf_games['Div_Home'][conf_games['H_WinTeam']==1].value_counts()['AFC North'] + 
             conf_games['Div_Away'][conf_games['H_WinTeam']==0].value_counts()['AFC North'])
afc_south = (conf_games['Div_Home'][conf_games['H_WinTeam']==1].value_counts()['AFC South'] + 
             conf_games['Div_Away'][conf_games['H_WinTeam']==0].value_counts()['AFC South'])
afc_east = (conf_games['Div_Home'][conf_games['H_WinTeam']==1].value_counts()['AFC East'] + 
            conf_games['Div_Away'][conf_games['H_WinTeam']==0].value_counts()['AFC East'])
afc_west = (conf_games['Div_Home'][conf_games['H_WinTeam']==1].value_counts()['AFC West'] + 
            conf_games['Div_Away'][conf_games['H_WinTeam']==0].value_counts()['AFC West'])
nfc_north = (conf_games['Div_Home'][conf_games['H_WinTeam']==1].value_counts()['NFC North'] + 
             conf_games['Div_Away'][conf_games['H_WinTeam']==0].value_counts()['NFC North'])
nfc_south = (conf_games['Div_Home'][conf_games['H_WinTeam']==1].value_counts()['NFC South'] + 
             conf_games['Div_Away'][conf_games['H_WinTeam']==0].value_counts()['NFC South'])
nfc_east = (conf_games['Div_Home'][conf_games['H_WinTeam']==1].value_counts()['NFC East'] + 
            conf_games['Div_Away'][conf_games['H_WinTeam']==0].value_counts()['NFC East'])
nfc_west = (conf_games['Div_Home'][conf_games['H_WinTeam']==1].value_counts()['NFC West'] + 
            conf_games['Div_Away'][conf_games['H_WinTeam']==0].value_counts()['NFC West'])

#Looking to see what divisions in each confrences is the strongest when against other divisions
#Comparing games only played in their own conference but not in their own division

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,10))
fig.subplots_adjust(wspace=0)

#Creating NFC pie chart
nfc_labels = ['NFC North', 'NFC South', 'NFC East', 'NFC West']
nfc_values = [nfc_north, nfc_south, nfc_east, nfc_west]

patches, texts, pcts = ax1.pie(
    x=nfc_values, autopct='%.2f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90)
plt.setp(pcts, color='white', fontweight='bold')
ax1.set_title('NFC Games', fontsize=18)
ax1.legend(patches, nfc_labels,
          title="NFC Divisions",
          loc="center left",
          bbox_to_anchor=(-0.3, 0, 0.5, 1))

#Creating AFC pie chart
afc_labels = ['AFC North', 'AFC South', 'AFC East', 'AFC West']
afc_values = [afc_north, afc_south, afc_east, afc_west]

patches, texts, pcts = ax2.pie(
    x=afc_values, autopct='%.2f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90)
plt.setp(pcts, color='white', fontweight='bold')
ax2.set_title('AFC Games', fontsize=18)
ax2.legend(patches, afc_labels,
          title="AFC Divisions",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

fig.suptitle('Games Played Out of Division in Conference',x=0.5, y=0.8, fontsize=18, va='top')
# Out:
# Text(0.5, 0.8, 'Games Played Out of Division in Conference')

# %%
#Top team records in the NFC
print(conf_games[['Conf_Home', 'HomeTeam']][['HomeTeam','Conf_Home']].value_counts())
print(conf_games[['Conf_Away', 'AwayTeam']][['AwayTeam','Conf_Away']].value_counts())
# Out:
# HomeTeam    Conf_Home
# Patriots    AFC          62
# Chiefs      AFC          57
# Packers     NFC          55
# Saints      NFC          52
# Broncos     AFC          51
# Colts       AFC          51
# Seahawks    NFC          51
# Falcons     NFC          50
# Eagles      NFC          50
# 49ers       NFC          50
# Steeler     AFC          50
# Texans      AFC          50
# Panthers    NFC          50
# Cowboys     NFC          49
# Ravens      AFC          49
# Vikings     NFC          49
# Titans      AFC          48
# WashFB      NFC          48
# Chargers    AFC          48
# Cardinals   NFC          48
# Buccaneers  NFC          48
# Bengals     AFC          48
# Bears       NFC          47
# Rams        NFC          47
# Bills       AFC          47
# Giants      NFC          46
# Dolphins    AFC          46
# Jaguars     AFC          46
# Lions       NFC          45
# Jets        AFC          45
# Raiders     AFC          45
# Browns      AFC          45
# dtype: int64
# AwayTeam    Conf_Away
# Ravens      AFC          56
# Seahawks    NFC          55
# Packers     NFC          55
# Colts       AFC          52
# Titans      AFC          51
# Chargers    AFC          51
# 49ers       NFC          50
# Giants      NFC          50
# Bengals     AFC          50
# Steeler     AFC          50
# Saints      NFC          50
# Eagles      NFC          50
# Jets        AFC          50
# Vikings     NFC          49
# Texans      AFC          49
# Jaguars     AFC          49
# Falcons     NFC          49
# Cardinals   NFC          49
# Bills       AFC          49
# Patriots    AFC          48
# Rams        NFC          48
# Cowboys     NFC          48
# Chiefs      AFC          48
# Lions       NFC          47
# Raiders     AFC          47
# Buccaneers  NFC          47
# Bears       NFC          46
# Dolphins    AFC          46
# Panthers    NFC          46
# Browns      AFC          46
# Broncos     AFC          46
# WashFB      NFC          46
# dtype: int64

# %%
#Win percentage by conference - Bar plot
#Teams with best Away record and Home record

# %%
#Looking at teams in the top division of the NFC
#nfc_north, nfc_south, nfc_east, nfc_west
#nfc_labels, nfc_values

df_nfcsouth = conf_games[['H_WinTeam', 'HomeTeam', 'AwayTeam'
                 ]][(nfl['Div_Home']=='NFC South') | (nfl['Div_Away']=='NFC South')]


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,10))
fig.subplots_adjust(wspace=0)

#Creating bar chart for the NFC South
afc_labels = ['AFC North', 'AFC South', 'AFC East', 'AFC West']
afc_values = [afc_north, afc_south, afc_east, afc_west]
bottom = 1
width = 0.2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(afc_values, afc_labels)])):
    bottom -= height
    bc = ax3.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax3.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax3.set_title('AFC Divisions')
ax3.legend(bbox_to_anchor=(1.02, 1), loc='upper center', borderaxespad=0)
ax3.axis('off')
ax3.set_xlim(- 2.5 * width, 2.5 * width)

# Get four different grey colors.
cmap = plt.get_cmap('Greys')
colors = list(cmap(np.linspace(0.45, 0.85, len(nfc_values))))
# Swap in a bright blue for the Lacrosse color.
colors[3] = 'dodgerblue'

# You could also just manually assign colors very easily.
# colors = ['purple', 'black', 'pink', 'aqua']

patches, texts, pcts = ax2.pie(
    nfc_values, labels=nfc_labels, autopct='%.1f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90,
    colors=colors,
    # "Explode" the Lacrosse wedge to highlight it.
    explode=(0, 0, 0, 0.1))

for i, patch in enumerate(patches):
  # You could also do something like this if you want to assign colors
  # by some rule or by value.
  # if texts[i].get_text() == 'Lacrosse':
  #   patch.set_facecolor('dodgerblue')
  texts[i].set_color(patch.get_facecolor())
plt.setp(pcts, color='white')
plt.setp(texts, fontweight=600)
ax2.set_title('Best NFC Division', fontsize=18)
plt.tight_layout()

# %%
#Comparing games the NFC played the AFC
#Calculating values counts for each conference and division in the NFL
out_conf = nfl[['H_WinTeam','Conf_Home','Conf_Away', 'Div_Home', 'Div_Away']][nfl['Conf_Home']!=nfl['Conf_Away']]
afc_sum = out_conf['Conf_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC'] + out_conf['Conf_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC']
nfc_sum = out_conf['Conf_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC'] + out_conf['Conf_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC']
afc_north = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC North'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC North'])/out_conf.shape[0]
afc_south = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC South'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC South'])/out_conf.shape[0]
afc_east = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC East'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC East'])/out_conf.shape[0]
afc_west = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC West'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC West'])/out_conf.shape[0]
nfc_north = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC North'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC North'])/out_conf.shape[0]
nfc_south = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC South'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC South'])/out_conf.shape[0]
nfc_east = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC East'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC East'])/out_conf.shape[0]
nfc_west = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC West'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC West'])/out_conf.shape[0]

print('NFC Games Won: ' + str(nfc_sum))
print('AFC Games Won: ' + str(afc_sum))


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9,5))
fig.subplots_adjust(wspace=0)

#Creating Pie Chart
labels = ['National Football Confrence_NFC', 'American Football Confrence_AFC']
values = [nfc_sum, afc_sum]

# Get four different grey colors.
cmap = plt.get_cmap('Greys')
colors = list(cmap(np.linspace(0.45, 0.85, len(values))))
# Swap in a bright blue for the Lacrosse color.
colors[0] = 'dodgerblue'

# You could also just manually assign colors very easily.
# colors = ['purple', 'black', 'pink', 'aqua']

patches, texts, pcts = ax1.pie(
    x=values, labels=labels, autopct='%.2f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90,
    colors=colors,
    # "Explode" the Lacrosse wedge to highlight it.
    explode=(0, 0.1))

for i, patch in enumerate(patches):
  # You could also do something like this if you want to assign colors
  # by some rule or by value.
  # if texts[i].get_text() == 'Lacrosse':
  #   patch.set_facecolor('dodgerblue')
  texts[i].set_color(patch.get_facecolor())
plt.setp(pcts, color='white')
plt.setp(texts, fontweight=600)
ax1.set_title('Sport Popularity', fontsize=18)
#plt.tight_layout()
# Out:
# NFC Games Won: 491
# AFC Games Won: 480
# Text(0.5, 1.0, 'Sport Popularity')

# %%
#Comparing confrences NFC vs AFC

#Calculating values counts for each conference and division in the NFL
out_conf = nfl[['H_WinTeam','Conf_Home','Conf_Away', 'Div_Home', 'Div_Away']][nfl['Conf_Home']!=nfl['Conf_Away']]
afc_sum = out_conf['Conf_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC'] + out_conf['Conf_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC']
nfc_sum = out_conf['Conf_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC'] + out_conf['Conf_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC']
afc_north = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC North'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC North'])/out_conf.shape[0]
afc_south = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC South'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC South'])/out_conf.shape[0]
afc_east = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC East'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC East'])/out_conf.shape[0]
afc_west = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['AFC West'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['AFC West'])/out_conf.shape[0]
nfc_north = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC North'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC North'])/out_conf.shape[0]
nfc_south = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC South'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC South'])/out_conf.shape[0]
nfc_east = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC East'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC East'])/out_conf.shape[0]
nfc_west = (out_conf['Div_Home'][out_conf['H_WinTeam']==1].value_counts()['NFC West'] + out_conf['Div_Away'][out_conf['H_WinTeam']==0].value_counts()['NFC West'])/out_conf.shape[0]

print('NFC Games Won: ' + str(nfc_sum))
print('AFC Games Won: ' + str(afc_sum))

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(9,5))
fig.subplots_adjust(wspace=0)

#Creating Pie Chart
labels = ['National Football Confrence_NFC', 'American Football Confrence_AFC']
values = [nfc_sum, afc_sum]
#explode = [0.1, 0, 0]
ax2.pie(x=values, labels=labels, autopct='%.2f%%',
       wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
       textprops={'size': 'x-large'})


#Creating bar chart for the NFC
nfc_labels = ['NFC North', 'NFC South', 'NFC East', 'NFC West']
nfc_values = [nfc_north, nfc_south, nfc_east, nfc_west]
bottom = 1
width = 0.2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(nfc_values, nfc_labels)])):
    bottom -= height
    bc = ax1.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax1.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax1.set_title('NFC Divisions')
ax1.legend(bbox_to_anchor=(0.2, 1), loc='upper right', borderaxespad=0)
ax1.axis('off')
ax1.set_xlim(- 2.5 * width, 2.5 * width)

#Creating bar chart for the AFC
afc_labels = ['AFC North', 'AFC South', 'AFC East', 'AFC West']
afc_values = [afc_north, afc_south, afc_east, afc_west]
bottom = 1
width = 0.2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(afc_values, afc_labels)])):
    bottom -= height
    bc = ax3.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax3.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax3.set_title('AFC Divisions')
ax3.legend(bbox_to_anchor=(1.02, 1), loc='upper center', borderaxespad=0)
ax3.axis('off')
ax3.set_xlim(- 2.5 * width, 2.5 * width)


plt.show()
# Out:
# NFC Games Won: 491
# AFC Games Won: 480

# %%
nfl['Conf_Home'][nfl['H_WinTeam']==1].value_counts()
# Out:
# AFC    1143
# NFC    1104
# Name: Conf_Home, dtype: int64

# %%
nfl['Conf_Away'][nfl['H_WinTeam']==0].value_counts()
# Out:
# NFC    899
# AFC    853
# Name: Conf_Away, dtype: int64

# %%
nfl['Conf_Away'][nfl['H_WinTeam']==0].value_counts()['NFC']
# Out:
# 899

# %%
out_conf = nfl[['H_WinTeam','Conf_Home','Conf_Away']][nfl['Conf_Home']!=nfl['Conf_Away']]

# %%
out_conf.shape[0]
# Out:
# 971

# %%
print('Home Games Won: ' + str(nfl['Conf_Home'][nfl['H_WinTeam']==1].value_counts()[1]))
print('Away Games Won: ' + str(nfl['Conf_Away'][nfl['H_WinTeam']==0].value_counts()[0]))
labels = [nfl['Conf_Home']]
values = [nfl['H_WinTeam'].value_counts()[1]]
plt.pie(x=values, labels=labels, autopct='%.2f%%')
plt.show()
